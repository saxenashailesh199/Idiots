# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_train=pd.read_csv("train.csv")
df_test=pd.read_csv("test.csv")

# %%
print('The Shape Of training data:',df_train.shape)
print('The Shape Of testing data:',df_test.shape)
# Out:
# The Shape Of training data: (891, 12)
# The Shape Of testing data: (418, 11)

# %%
#Save the 'Id' column
train_Id = df_train['PassengerId']
PassengerId = df_test['PassengerId']

# %%
#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
#df_train.drop("PassengerId", axis = 1, inplace = True)
#df_test.drop("PassengerId", axis = 1, inplace = True)

# %%
df_train["source"]="train"
df_test["source"]="test"

# %%
df=pd.concat([df_train,df_test])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked source
# 0      0         A/5 21171   7.2500   NaN        S  train
# 1      0          PC 17599  71.2833   C85        C  train
# 2      0  STON/O2. 3101282   7.9250   NaN        S  train
# 3      0            113803  53.1000  C123        S  train
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305       NaN       3            Spector, Mr. Woolf    male
# 414         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 416         1308       NaN       3           Ware, Mr. Frederick    male
# 417         1309       NaN       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked source
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S   test
# 414  39.0      0      0            PC 17758  108.9000  C105        C   test
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test
# 416   NaN      0      0              359309    8.0500   NaN        S   test
# 417   NaN      1      1                2668   22.3583   NaN        C   test

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked source
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S   test
# 1305  39.0      0      0            PC 17758  108.9000  C105        C   test
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test
# 1307   NaN      0      0              359309    8.0500   NaN        S   test
# 1308   NaN      1      1                2668   22.3583   NaN        C   test

# %%
df['Members'] = df['SibSp'] + df['Parch'] + 1

# %%
#survival:    Survival 
#PassengerId: Unique Id of a passenger. 
#pclass:    Ticket class     
#Sex:    Sex     
#Age:    Age in years     
#sibsp:    # of siblings / spouses aboard the Titanic     
#parch:    # of parents / children aboard the Titanic     
#ticket:    Ticket number     
#fare:    Passenger fare     
#cabin:    Cabin number     
#embarked:    Port of Embarkation(C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
df[['Last_name','First_name']] = df['Name'].str.split(pat=",", n=1, expand=True)
df[['Title','First_name']] = df['First_name'].str.split(pat=".", n=1, expand=True)
df['Title'] = df['Title'].str.strip()
df['Last_name'] = df['Last_name'].str.strip()
df = df.drop('Name', axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1       0.0       3    male  22.0      1      0
# 1            2       1.0       1  female  38.0      1      0
# 2            3       1.0       3  female  26.0      0      0
# 3            4       1.0       1  female  35.0      1      0
# 4            5       0.0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked source  Members  Last_name  \
# 0         A/5 21171   7.2500   NaN        S  train        2     Braund
# 1          PC 17599  71.2833   C85        C  train        2    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  train        1  Heikkinen
# 3            113803  53.1000  C123        S  train        2   Futrelle
# 4            373450   8.0500   NaN        S  train        1      Allen
#
#                                First_name Title
# 0                             Owen Harris    Mr
# 1   John Bradley (Florence Briggs Thayer)   Mrs
# ...

# %% [markdown]
# # Ticket

# %%
df[['Ticket']] = df['Ticket'].str.upper()

# %% [markdown]
# # Ticket Start with 'A'

# %%
df[(df.Ticket.str[0]=='A')].Ticket.value_counts()
# Out:
# A/4 48871      3
# A/5. 851       3
# A/5. 3337      2
# A/5. 3336      2
# A./5. 3338     1
# A/4 45380      1
# A/5 21174      1
# A/5 2817       1
# A/5. 2151      1
# A./5. 3235     1
# A/5 3594       1
# A/4. 20589     1
# AQ/4 3130      1
# A/5 21173      1
# A. 2. 39186    1
# A/5 2466       1
# A/4. 34244     1
# A/5. 10482     1
# A.5. 18509     1
# A/5 3540       1
# A/5. 13032     1
# A4. 54510      1
# A./5. 2152     1
# A/5 3536       1
# A/5 1478       1
# A/4 48873      1
# A/5 3902       1
# A.5. 11206     1
# A.5. 3236      1
# A/5 21172      1
# AQ/3. 30631    1
# A/S 2816       1
# A/5 21171      1
# A/4. 39886     1
# A/4 31416      1
# A/5 21175      1
# Name: Ticket, dtype: int64

# %%
df['Ticket'] = df.Ticket.str.replace('A. 2.','A/2')
df['Ticket'] = df.Ticket.str.replace('AQ/3.','AQ/3')
df['Ticket'] = df.Ticket.str.replace('A/4. 39886','A/4 39886')
df['Ticket'] = df.Ticket.str.replace('A/4. 20589','A/4 20589')
df['Ticket'] = df.Ticket.str.replace('A/4. 34244','A/4 34244')
df['Ticket'] = df.Ticket.str.replace('A4. 54510','A/4 54510')
df['Ticket'] = df.Ticket.str.replace('A./5.','A/5')
df['Ticket'] = df.Ticket.str.replace('A/5. 851','A/5 851')
df['Ticket'] = df.Ticket.str.replace('A/5. 3337','A/5 3337')
df['Ticket'] = df.Ticket.str.replace('A/5. 3336','A/5 3336')
df['Ticket'] = df.Ticket.str.replace('A/5. 2151','A/5 2151')
df['Ticket'] = df.Ticket.str.replace('A/5. 10482','A/5 10482')
df['Ticket'] = df.Ticket.str.replace('A/5. 13032','A/5 13032')
df['Ticket'] = df.Ticket.str.replace('A.5. 11206','A/5 11206')
df['Ticket'] = df.Ticket.str.replace('A.5. 18509','A/5 18509')
df['Ticket'] = df.Ticket.str.replace('A.5. 11206','A/5 11206')
df['Ticket'] = df.Ticket.str.replace('A.5. 3236','A/5 3236')

# %%
df[(df.Ticket.str[0]=='A')].Ticket.value_counts()
# Out:
# A/4 48871     3
# A/5 851       3
# A/5 3337      2
# A/5 3336      2
# A/5 10482     1
# A/5 3236      1
# A/4 31416     1
# A/5 3594      1
# A/5 2151      1
# A/5 2466      1
# A/5 11206     1
# A/5 3540      1
# A/5 18509     1
# A/4 48873     1
# A/5 21173     1
# A/4 54510     1
# A/4 34244     1
# A/5 21175     1
# A/5 2817      1
# A/4 45380     1
# A/5 2152      1
# A/2 39186     1
# AQ/4 3130     1
# A/5 1478      1
# A/5 3338      1
# A/4 39886     1
# A/4 20589     1
# AQ/3 30631    1
# A/5 3536      1
# A/5 3902      1
# A/5 21172     1
# A/5 21174     1
# A/S 2816      1
# A/5 21171     1
# A/5 3235      1
# A/5 13032     1
# Name: Ticket, dtype: int64

# %% [markdown]
# # Ticket Start with 'C'

# %%
df[(df.Ticket.str[0]=='C')].Ticket.value_counts()
# Out:
# CA/243              11
# CA 2144              8
# C.A/215              4
# C.A. 34651           4
# C.A. 33112           4
# C 4001               3
# C.A. 31921           3
# C.A/273              3
# C.A. 37671           3
# C.A. 31029           3
# C.A. 6212            2
# C.A. 33595           2
# CA 31352             2
# C.A. 31026           1
# C.A/2580             1
# C.A. 34260           1
# C 7077               1
# C.A. 42795           1
# C 17368              1
# C 7075               1
# C.A. 33111           1
# C.A/2395             1
# C.A. 30769           1
# C 17369              1
# C.A. 15185           1
# C.A. 31030           1
# CA/214               1
# C 7076               1
# C.A. 17248           1
# C.A/2566             1
# C.A. 34644           1
# C.A/2579             1
# C.A. 49867           1
# C.A/2178             1
# C.A. 5547            1
# C.A./SOTON 34068     1
# C.A. 34050           1
# C.A. 18723           1
# Name: Ticket, dtype: int64

# %%
df['Ticket'] = df.Ticket.str.replace('CA.','CA')
df['Ticket'] = df.Ticket.str.replace('C.A.','CA')
df['Ticket'] = df.Ticket.str.replace('CA2144','CA 2144')
df['Ticket'] = df.Ticket.str.replace('CA31352','CA 31352')
df['Ticket'] = df.Ticket.str.replace('CA243','CA 243')
df['Ticket'] = df.Ticket.str.replace('CA215','CA 215')
df['Ticket'] = df.Ticket.str.replace('CA273','CA 273')
df['Ticket'] = df.Ticket.str.replace('CA2580','CA 2580')
df['Ticket'] = df.Ticket.str.replace('CA214','CA 214')
df['Ticket'] = df.Ticket.str.replace('CA2579','CA 2579')
df['Ticket'] = df.Ticket.str.replace('CA2178','CA 2178')
df['Ticket'] = df.Ticket.str.replace('CA2395','CA 2395')
df['Ticket'] = df.Ticket.str.replace('CA2566','CA 2566')

# %%
df[(df.Ticket.str[0]=='C')].Ticket.value_counts()
# Out:
# CA 243            11
# CA 2144            8
# CA 215             4
# CA 34651           4
# CA 33112           4
# CA 37671           3
# CA 273             3
# CA 31921           3
# CA 31029           3
# C 4001             3
# CA 31352           2
# CA 33595           2
# CA 6212            2
# CA 214             1
# CA 17248           1
# C 7075             1
# CA 42795           1
# C 7077             1
# CA 34644           1
# CA 33111           1
# CA 31026           1
# CA 34260           1
# CA 2566            1
# CA 2579            1
# CA/SOTON 34068     1
# CA 15185           1
# CA 2580            1
# C 17369            1
# CA 18723           1
# CA 30769           1
# CA 5547            1
# C 7076             1
# C 17368            1
# CA 31030           1
# CA 49867           1
# CA 34050           1
# CA 2395            1
# CA 2178            1
# Name: Ticket, dtype: int64

# %% [markdown]
# # Ticket Start with 'F'

# %%
df[(df.Ticket.str[0]=='F')].Ticket.value_counts()
# Out:
# F.C.C. 13529    3
# F.C. 12750      2
# F.C.C. 13528    2
# F.C.C. 13534    2
# FA 265302       1
# F.C.C. 13540    1
# F.C.C. 13531    1
# F.C. 12998      1
# Name: Ticket, dtype: int64

# %%
df['Ticket'] = df.Ticket.str.replace('F.C.C.','FCC')
df['Ticket'] = df.Ticket.str.replace('F.C. 12750','FC 12750')
df['Ticket'] = df.Ticket.str.replace('F.C. 12998','FC 12998')

# %%
df[(df.Ticket.str[0]=='F')].Ticket.value_counts()
# Out:
# FCC 13529    3
# FCC 13528    2
# FC 12750     2
# FCC 13534    2
# FA 265302    1
# FC 12998     1
# FCC 13531    1
# FCC 13540    1
# Name: Ticket, dtype: int64

# %% [markdown]
# # Ticket Start with 'S'

# %%
df[(df.Ticket.str[0]=='S')].Ticket.value_counts()
# Out:
# S.O.C. 14879          7
# SC/PARIS 2123         4
# S.C./PARIS 2079       3
# SOTON/O.Q. 3101315    3
# S.O./P.P. 3           2
# SC/PARIS 2167         2
# STON/O2. 3101279      2
# S.O./P.P. 2           2
# SCA2037               2
# SCA 3085              2
# SOTON/O.Q. 3101310    1
# STON/O2. 3101283      1
# STON/O 2. 3101280     1
# SOTON/OQ 3101317      1
# SC 14888              1
# SOTON/OQ 392090       1
# SOTON/O.Q. 3101314    1
# SW/PP 751             1
# SCA3 2861             1
# SCA2568               1
# SOTON/O2 3101272      1
# SOTON/O.Q. 3101308    1
# STON/O 2. 3101291     1
# SOTON/OQ 3101316      1
# STON/O 2. 3101273     1
# STON/O 2. 3101294     1
# STON/O 2. 3101293     1
# SOTON/O2 3101287      1
# STON/O 2. 3101286     1
# SOTON/O.Q. 392078     1
# STON/O 2. 3101288     1
# SOTON/O.Q. 3101262    1
# S.O./P.P. 752         1
# STON/O 2. 3101289     1
# SC/PARIS 2148         1
# STON/OQ. 369943       1
# STON/O2. 3101282      1
# SOTON/O.Q. 3101312    1
# ...

# %%
df['Ticket'] = df.Ticket.str.replace('S.O.C.','SOC')
df['Ticket'] = df.Ticket.str.replace('S.C./PARIS','SC/PARIS')
df['Ticket'] = df.Ticket.str.replace('SOTON/O.Q.','SOTON/OQ')
df['Ticket'] = df.Ticket.str.replace('S.O./P.P.','SO/PP')
df['Ticket'] = df.Ticket.str.replace('STON/O 2.','STON/O2')
df['Ticket'] = df.Ticket.str.replace('STON/OQ.','STON/OQ')
df['Ticket'] = df.Ticket.str.replace('STON/O2.','STON/O2')
df['Ticket'] = df.Ticket.str.replace('S.P.','SP')
df['Ticket'] = df.Ticket.str.replace('S.O.P.','SOP')
df['Ticket'] = df.Ticket.str.replace('S.C./A.4.','SC/A4')
df['Ticket'] = df.Ticket.str.replace('S.W./PP','SW/PP')
df['Ticket'] = df.Ticket.str.replace('STON/O23101273','STON/O2 3101273')
df['Ticket'] = df.Ticket.str.replace('STON/O23101275','STON/O2 3101275')
df['Ticket'] = df.Ticket.str.replace('STON/O23101292','STON/O2 3101292')
df['Ticket'] = df.Ticket.str.replace('STON/O23101289','STON/O2 3101289')
df['Ticket'] = df.Ticket.str.replace('STON/O23101274','STON/O2 3101274')
df['Ticket'] = df.Ticket.str.replace('STON/O23101268','STON/O2 3101268')
df['Ticket'] = df.Ticket.str.replace('STON/O23101285','STON/O2 3101285')
df['Ticket'] = df.Ticket.str.replace('STON/O23101269','STON/O2 3101269')
df['Ticket'] = df.Ticket.str.replace('STON/O23101286','STON/O2 3101286')
df['Ticket'] = df.Ticket.str.replace('STON/O23101293','STON/O2 3101293')
df['Ticket'] = df.Ticket.str.replace('STON/O23101291','STON/O2 3101291')
df['Ticket'] = df.Ticket.str.replace('STON/O23101288','STON/O2 3101288')
df['Ticket'] = df.Ticket.str.replace('STON/O23101294','STON/O2 3101294')
df['Ticket'] = df.Ticket.str.replace('STON/O23101280','STON/O2 3101280')
df['Ticket'] = df.Ticket.str.replace('SCA2037','SCA 2037')
df['Ticket'] = df.Ticket.str.replace('SCA2568','SCA 2568')
df[(df.Ticket.str[0:7]=='STON/O2')].Ticket.value_counts()
# Out:
# STON/O2 3101279    2
# STON/O2 3101280    1
# STON/O2 3101286    1
# STON/O2 3101294    1
# STON/O2 3101293    1
# STON/O2 3101274    1
# STON/O2 3101270    1
# STON/O2 3101289    1
# STON/O2 3101288    1
# STON/O2 3101285    1
# STON/O2 3101283    1
# STON/O2 3101275    1
# STON/O2 3101271    1
# STON/O2 3101273    1
# STON/O2 3101291    1
# STON/O2 3101268    1
# STON/O2 3101290    1
# STON/O2 3101269    1
# STON/O2 3101292    1
# STON/O2 3101282    1
# Name: Ticket, dtype: int64

# %%
df[(df.Ticket.str[0]=='S')].Ticket.value_counts()
# Out:
# SOC 14879           7
# SC/PARIS 2123       4
# SOTON/OQ 3101315    3
# SC/PARIS 2079       3
# SCA 3085            2
# SCA 2037            2
# SO/PP 3             2
# STON/O2 3101279     2
# SC/PARIS 2167       2
# SO/PP 2             2
# SW/PP 751           1
# STON/OQ 369943      1
# SC 14888            1
# SOTON/OQ 3101263    1
# STON/O2 3101289     1
# SP 3464             1
# SO/PP 752           1
# SOTON/OQ 3101316    1
# STON/O2 3101275     1
# SCA3 2861           1
# STON/O2 3101271     1
# SOTON/O2 3101272    1
# SOTON/OQ 3101262    1
# STON/O2 3101293     1
# SOTON/OQ 3101317    1
# STON/O2 3101286     1
# SC 1748             1
# SCA 2568            1
# SOTON/OQ 3101311    1
# STON/O2 3101268     1
# STON/O2 3101273     1
# SOTON/OQ 392083     1
# SOTON/OQ 3101307    1
# SC/PARIS 2148       1
# SOTON/OQ 392076     1
# STON/O2 3101285     1
# STON/O2 3101269     1
# SCO/W 1585          1
# STON/O2 3101274     1
# SOTON/OQ 392089     1
# SC/PARIS 2146       1
# ...

# %% [markdown]
# # Ticket Start with 'W'

# %%
df[(df.Ticket.str[0]=='W')].Ticket.value_counts()
# Out:
# W./C. 6608     5
# W./C. 6607     4
# WE/P 5735      2
# W.E.P. 5734    2
# W./C. 6609     1
# W/C 14208      1
# W./C. 14263    1
# W./C. 14266    1
# W./C. 14260    1
# W./C. 14258    1
# Name: Ticket, dtype: int64

# %%
df['Ticket'] = df.Ticket.str.replace('W./C.','W/C')
df['Ticket'] = df.Ticket.str.replace('WE/P','WEP')
df['Ticket'] = df.Ticket.str.replace('W.E.P.','WEP')

# %%
df[(df.Ticket.str[0]=='W')].Ticket.value_counts()
# Out:
# W/C 6608     5
# W/C 6607     4
# WEP 5734     2
# WEP 5735     2
# W/C 14258    1
# W/C 14208    1
# W/C 14260    1
# W/C 14263    1
# W/C 14266    1
# W/C 6609     1
# Name: Ticket, dtype: int64

# %% [markdown]
# # EMBARKED

# %%
df[(df.Embarked.isnull())]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  Fare  \
# 61            62       1.0       1  female  38.0      0      0  113572  80.0
# 829          830       1.0       1  female  62.0      0      0  113572  80.0
#
#     Cabin Embarked source  Members Last_name                      First_name  \
# 61    B28      NaN  train        1     Icard                          Amelie
# 829   B28      NaN  train        1     Stone   George Nelson (Martha Evelyn)
#
#     Title
# 61   Miss
# 829   Mrs

# %%
df[(df.Ticket.str.len()==6)&(df.Pclass==1)&(df.Cabin.str[0]=='B')].sort_values('Ticket',ascending=False)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  \
# 802           803       1.0       1    male  11.0      1      2  113760
# 763           764       1.0       1  female  36.0      1      2  113760
# 390           391       1.0       1    male  36.0      1      2  113760
# 435           436       1.0       1  female  14.0      1      2  113760
# 61             62       1.0       1  female  38.0      0      0  113572
# 829           830       1.0       1  female  62.0      0      0  113572
# 54             55       0.0       1    male  65.0      0      1  113509
# 917           918       NaN       1  female  22.0      0      1  113509
# 536           537       0.0       1    male  45.0      0      0  113050
# 1106         1107       NaN       1    male  42.0      0      0  113038
# 1196         1197       NaN       1  female  64.0      1      1  112901
# 263           264       0.0       1    male  40.0      0      0  112059
# ...

# %%
# Substitute the value 'S'

# %%
df.Embarked.fillna('S',inplace=True)

# %% [markdown]
# # DONE CLEANING ON TICKET COLUMN

# %%
df_fare = df.sort_values('Fare',ascending=False)

# %% [markdown]
# # NULL VALUES

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          0
# source            0
# Members           0
# Last_name         0
# First_name        0
# Title             0
# dtype: int64

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Ticket  \
# 0            1       0.0       3    male  22.0      1      0  A/5 21171
# 1            2       1.0       1  female  38.0      1      0   PC 17599
#
#       Fare Cabin Embarked source  Members Last_name  \
# 0   7.2500   NaN        S  train        2    Braund
# 1  71.2833   C85        C  train        2   Cumings
#
#                                First_name Title
# 0                             Owen Harris    Mr
# 1   John Bradley (Florence Briggs Thayer)   Mrs

# %% [markdown]
# # Cabin

# %%
df['deck'] = df['Cabin'].copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch           Ticket  \
# 0            1       0.0       3    male  22.0      1      0        A/5 21171
# 1            2       1.0       1  female  38.0      1      0         PC 17599
# 2            3       1.0       3  female  26.0      0      0  STON/O2 3101282
# 3            4       1.0       1  female  35.0      1      0           113803
# 4            5       0.0       3    male  35.0      0      0           373450
#
#       Fare Cabin Embarked source  Members  Last_name  \
# 0   7.2500   NaN        S  train        2     Braund
# 1  71.2833   C85        C  train        2    Cumings
# 2   7.9250   NaN        S  train        1  Heikkinen
# 3  53.1000  C123        S  train        2   Futrelle
# 4   8.0500   NaN        S  train        1      Allen
#
#                                First_name Title  deck
# 0                             Owen Harris    Mr   NaN
# 1   John Bradley (Florence Briggs Thayer)   Mrs   C85
# ...

# %%
df[(df.Cabin.str[0]=='A')].PassengerId.count()
# Out:
# 22

# %%
df[(df.Cabin.str[0]=='B')].PassengerId.count()
# Out:
# 65

# %%
df[(df.Cabin.str[0]=='C')].PassengerId.count()
# Out:
# 94

# %%
df[(df.Cabin.str[0]=='D')].PassengerId.count()
# Out:
# 46

# %%
df[(df.Cabin.str[0]=='E')].PassengerId.count()
# Out:
# 41

# %%
df[(df.Cabin.str[0]=='F')].PassengerId.count()
# Out:
# 21

# %%
df[(df.Cabin.str[0]=='G')].PassengerId.count()
# Out:
# 5

# %%
df[(df.Cabin.str[0]=='A')]
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 23             24       1.0       1    male  28.0      0      0    113788
# 96             97       0.0       1    male  71.0      0      0  PC 17754
# 174           175       0.0       1    male  56.0      0      0     17764
# 185           186       0.0       1    male   NaN      0      0    113767
# 209           210       1.0       1    male  40.0      0      0    112277
# 284           285       0.0       1    male   NaN      0      0    113056
# 445           446       1.0       1    male   4.0      0      2     33638
# 475           476       0.0       1    male   NaN      0      0    110465
# 556           557       1.0       1  female  48.0      1      0     11755
# 583           584       0.0       1    male  36.0      0      0     13049
# 599           600       1.0       1    male  49.0      1      0  PC 17485
# 630           631       1.0       1    male  80.0      0      0     27042
# ...

# %%
df[(df.Cabin.str[0]=='B')]
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 31             32       1.0       1  female   NaN      1      0  PC 17569
# 54             55       0.0       1    male  65.0      0      1    113509
# 61             62       1.0       1  female  38.0      0      0    113572
# 118           119       0.0       1    male  24.0      0      1  PC 17558
# 139           140       0.0       1    male  24.0      0      0  PC 17593
# 170           171       0.0       1    male  61.0      0      0    111240
# 194           195       1.0       1  female  44.0      0      0  PC 17610
# 195           196       1.0       1  female  58.0      0      0  PC 17569
# 257           258       1.0       1  female  30.0      0      0    110152
# 263           264       0.0       1    male  40.0      0      0    112059
# 291           292       1.0       1  female  19.0      1      0     11967
# 299           300       1.0       1  female  50.0      0      1  PC 17558
# ...

# %%
df[(df.Cabin.str[0]=='C')]
# Out:
#       PassengerId  Survived  Pclass     Sex    Age  SibSp  Parch    Ticket  \
# 1               2       1.0       1  female  38.00      1      0  PC 17599
# 3               4       1.0       1  female  35.00      1      0    113803
# 11             12       1.0       1  female  58.00      0      0    113783
# 27             28       0.0       1    male  19.00      3      2     19950
# 55             56       1.0       1    male    NaN      0      0     19947
# 62             63       0.0       1    male  45.00      1      0     36973
# 88             89       1.0       1  female  23.00      3      2     19950
# 110           111       0.0       1    male  47.00      0      0    110465
# 137           138       0.0       1    male  37.00      1      0    113803
# 151           152       1.0       1  female  22.00      1      0    113776
# 177           178       0.0       1  female  50.00      0      0  PC 17595
# ...

# %%
df[(df.Cabin.str[0]=='D')].sort_values('Pclass',ascending=True)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 645           646       1.0       1    male  48.0      1      0
# 1295         1296       NaN       1    male  43.0      1      0
# 659           660       0.0       1    male  58.0      0      2
# 681           682       1.0       1    male  27.0      0      0
# 740           741       1.0       1    male   NaN      0      0
# 748           749       0.0       1    male  19.0      1      0
# 765           766       1.0       1  female  51.0      1      0
# 782           783       0.0       1    male  29.0      0      0
# 796           797       1.0       1  female  49.0      0      0
# 853           854       1.0       1  female  16.0      0      1
# 862           863       1.0       1  female  48.0      0      0
# 871           872       1.0       1  female  47.0      1      1
# 932           933       NaN       1    male   NaN      0      0
# 935           936       NaN       1  female  45.0      1      0
# ...

# %%
df[(df.Cabin.str[0]=='E')].sort_values('Pclass',ascending=True)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 6               7       0.0       1    male  54.0      0      0
# 1255         1256       NaN       1  female  25.0      1      0
# 662           663       0.0       1    male  47.0      0      0
# 701           702       1.0       1    male  35.0      0      0
# 707           708       1.0       1    male  42.0      0      0
# 724           725       1.0       1    male  27.0      1      0
# 809           810       1.0       1  female  33.0      1      0
# 835           836       1.0       1  female  39.0      1      1
# 857           858       1.0       1    male  51.0      0      0
# 905           906       NaN       1  female  47.0      1      0
# 1037         1038       NaN       1    male   NaN      0      0
# 1070         1071       NaN       1  female  64.0      0      2
# 1072         1073       NaN       1    male  37.0      1      1
# 1087         1088       NaN       1    male   6.0      0      2
# ...

# %%
df[(df.Cabin.str[0]=='E')]['Cabin'].str.split(pat="E", n=1, expand=True)
# Out:
#      0       1
# 6           46
# 92          31
# 123        101
# 166         33
# 262         67
# 303        101
# 309         36
# 319         34
# 337         40
# 356         33
# 370         50
# 429         10
# 434         44
# 456         38
# 460         12
# 462         63
# 512         25
# 558         67
# 572         25
# 577         44
# 585         68
# 662         58
# 701         24
# 707         24
# 717        101
# 724          8
# 751        121
# 772         77
# 809          8
# 823        121
# 835         49
# 857         17
# 905         31
# 1037        46
# 1070        45
# 1072        52
# 1087        34
# 1133        34
# 1246        60
# 1255        50
# 1262    39 E41

# %%
df[(df.Cabin.str[0]=='F')].sort_values('Pclass',ascending=True)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Ticket  \
# 66             67       1.0       2  female  29.0      0      0    CA 2395
# 1113         1114       NaN       2  female  22.0      0      0  W/C 14266
# 1069         1070       NaN       2  female  36.0      0      3     230136
# 1000         1001       NaN       2    male  18.5      0      0     248734
# 1213         1214       NaN       2    male  26.0      0      0     244368
# 618           619       1.0       2  female   4.0      2      1     230136
# 516           517       1.0       2  female  34.0      0      0   CA 34260
# 1217         1218       NaN       2  female  12.0      2      1     230136
# 340           341       1.0       2    male   2.0      1      1     230080
# 193           194       1.0       2    male   3.0      1      1     230080
# 183           184       1.0       2    male   1.0      2      1     230136
# ...

# %%
df[(df.Cabin.str[0]=='G')]
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 10             11       1.0       3  female   4.0      1      1  PP 9549
# 205           206       0.0       3  female   2.0      0      1   347054
# 251           252       0.0       3  female  29.0      1      1   347054
# 394           395       1.0       3  female  24.0      0      2  PP 9549
# 1008         1009       NaN       3  female   1.0      1      1  PP 9549
#
#          Fare Cabin Embarked source  Members  Last_name  \
# 10    16.7000    G6        S  train        3  Sandstrom
# 205   10.4625    G6        S  train        2      Strom
# 251   10.4625    G6        S  train        3      Strom
# 394   16.7000    G6        S  train        3  Sandstrom
# 1008  16.7000    G6        S   test        3  Sandstrom
#
#                                 First_name Title deck
# 10                          Marguerite Rut  Miss   G6
# 205                          Telma Matilda  Miss   G6
# ...

# %%
df[(df.Cabin.str[0]=='G')]['deck'].str.split(pat="G")
# Out:
# 10      [, 6]
# 205     [, 6]
# 251     [, 6]
# 394     [, 6]
# 1008    [, 6]
# Name: deck, dtype: object

# %%
df[['deck1','C1']] = df['deck'].str.split(pat="G", n=1, expand=True)

# %%
df[(df.Cabin.str[0]=='G')]
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 10             11       1.0       3  female   4.0      1      1  PP 9549
# 205           206       0.0       3  female   2.0      0      1   347054
# 251           252       0.0       3  female  29.0      1      1   347054
# 394           395       1.0       3  female  24.0      0      2  PP 9549
# 1008         1009       NaN       3  female   1.0      1      1  PP 9549
#
#          Fare Cabin Embarked source  Members  Last_name  \
# 10    16.7000    G6        S  train        3  Sandstrom
# 205   10.4625    G6        S  train        2      Strom
# 251   10.4625    G6        S  train        3      Strom
# 394   16.7000    G6        S  train        3  Sandstrom
# 1008  16.7000    G6        S   test        3  Sandstrom
#
#                                 First_name Title deck deck1 C1
# 10                          Marguerite Rut  Miss   G6        6
# ...

# %%
df.iloc[371]

# %%
df['Cabin'].str.split(pat=",", n=1, expand=True)

# %%
s.str.rsplit

# %%
df[(df.Cabin.str[0]=='F')].sort_values('Pclass',ascending=True)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Ticket  \
# 66             67       1.0       2  female  29.0      0      0    CA 2395
# 1113         1114       NaN       2  female  22.0      0      0  W/C 14266
# 1069         1070       NaN       2  female  36.0      0      3     230136
# 1000         1001       NaN       2    male  18.5      0      0     248734
# 1213         1214       NaN       2    male  26.0      0      0     244368
# 618           619       1.0       2  female   4.0      2      1     230136
# 516           517       1.0       2  female  34.0      0      0   CA 34260
# 1217         1218       NaN       2  female  12.0      2      1     230136
# 340           341       1.0       2    male   2.0      1      1     230080
# 193           194       1.0       2    male   3.0      1      1     230080
# 183           184       1.0       2    male   1.0      2      1     230136
# ...

# %%
df[(df.Cabin.str[0]=='F')&(df.Pclass==3)].sort_values('Embarked',ascending=True)
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  \
# 128           129       1.0       3  female   NaN      1      1    2668
# 1179         1180       NaN       3    male   NaN      0      0    2655
# 1212         1213       NaN       3    male  25.0      0      0    2654
# 776           777       0.0       3    male   NaN      0      0  383121
# 75             76       0.0       3    male  25.0      0      0  348123
# 699           700       0.0       3    male  42.0      0      0  348121
# 715           716       0.0       3    male  19.0      0      0  348124
# 948           949       NaN       3    male  25.0      0      0  348122
#
#          Fare  Cabin Embarked source  Members    Last_name  \
# 128   22.3583  F E69        C  train        3        Peter
# 1179   7.2292  F E46        C   test        1  Mardirosian
# 1212   7.2292  F E57        C   test        1    Krekorian
# 776    7.7500    F38        Q  train        1        Tobin
# ...

# %%
df[(df.Cabin.str[0]=='G')].sort_values('Ticket',ascending=True)

# %% [markdown]
# # We analyze  that Cabin Category are 'A','B','C','D','E','F','G'

# %%
df[(df.Cabin.str[0]=='A')].sort_values('Cabin',ascending=False)

# %%
df[(df.Cabin.isnull())&(df.Pclass==3)&((df.Fare<=23)&(df.Fare>=7.0000))].sort_values('Fare',ascending=True)

# %%
df[(df.Cabin.isnull())&(df.Pclass==3)&((df.Ticket.str[0:2]=='34'))]

# %%
df.sort_values('Ticket',ascending=False)
# Out:
#       PassengerId  Survived  Pclass     Sex    Age  SibSp  Parch  \
# 745           746       0.0       1    male  70.00      1      1
# 540           541       1.0       1  female  36.00      0      2
# 905           906       NaN       1  female  47.00      1      0
# 92             93       0.0       1    male  46.00      1      0
# 235           236       0.0       3  female    NaN      0      0
# 147           148       0.0       3  female   9.00      2      2
# 86             87       0.0       3    male  16.00      1      3
# 736           737       0.0       3  female  48.00      1      3
# 436           437       0.0       3  female  21.00      2      2
# 1058         1059       NaN       3    male  18.00      2      2
# 924           925       NaN       3  female    NaN      1      2
# 783           784       0.0       3    male    NaN      1      2
# 1135         1136       NaN       3    male    NaN      1      2
# ...
